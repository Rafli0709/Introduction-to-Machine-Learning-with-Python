# %% [markdown]
# # Chapter 5: Model Evaluation and Improvement
#
# ## Validasi Silang & Pencarian Parameter Hebat
# Menggunakan teknik `cross_val_score` untuk evaluasi performa model yang kuat dan `GridSearchCV` untuk tuning kombinasi parameter terbaik secara otomatis.

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.datasets import load_iris
from sklearn.svm import SVC

iris = load_iris()

# 1. Cross-Validation
svm = SVC(kernel='rbf', C=1, gamma='scale')
scores = cross_val_score(svm, iris.data, iris.target, cv=5)
print("Cross-validation scores:", scores)
print("Mean cross-validation score:", scores.mean())

# 2. Grid Search dengan Cross-Validation
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

grid_search = GridSearchCV(SVC(), param_grid, cv=5, n_jobs=-1)
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=0)

grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_:.3f}")
print(f"Test set score: {grid_search.score(X_test, y_test):.3f}")
